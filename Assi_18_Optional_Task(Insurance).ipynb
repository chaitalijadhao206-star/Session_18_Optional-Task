# %% [markdown]
# <a href="https://colab.research.google.com/github/chaitalijadhao206-star/Session_18_Optional-Task/blob/main/Assi_18_Optional_Task(Insurance).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7b08b917-a6a4-4e5f-a9c0-481e92d05eb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7b08b917-a6a4-4e5f-a9c0-481e92d05eb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("insurance.csv")
df
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
df.head(10)
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86
# 5   31  female  25.7         0     no  southeast   3756.62
# 6   46  female  33.4         1     no  southeast   8240.59
# 7   37  female  27.7         3     no  northwest   7281.51
# 8   37    male  29.8         2     no  northeast   6406.41
# 9   60  female  25.8         0     no  northwest  28923.14

# %%
df.tail()
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36

# %%
df.shape
# Out:
# (1338, 7)

# %%
df.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# expenses    float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# expenses    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#                age          bmi     children      expenses
# count  1337.000000  1337.000000  1337.000000   1337.000000
# mean     39.222139    30.665520     1.095737  13279.121638
# std      14.044333     6.100664     1.205571  12110.359657
# min      18.000000    16.000000     0.000000   1121.870000
# 25%      27.000000    26.300000     0.000000   4746.340000
# 50%      39.000000    30.400000     1.000000   9386.160000
# 75%      51.000000    34.700000     2.000000  16657.720000
# max      64.000000    53.100000     5.000000  63770.430000

# %%
df.min(numeric_only=True)
# Out:
# age           18.00
# bmi           16.00
# children       0.00
# expenses    1121.87
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# age            64.00
# bmi            53.10
# children        5.00
# expenses    63770.43
# dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# age            39.222139
# bmi            30.665520
# children        1.095737
# expenses    13279.121638
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# age           39.00
# bmi           30.40
# children       1.00
# expenses    9386.16
# dtype: float64

# %% [markdown]
# Q4

# %%
plt.hist(df["age"], bins=20)
plt.title("Age")
plt.show()

# %%
plt.hist(df["bmi"], bins=20)
plt.title("BMI")
plt.show()

# %%
plt.hist(df["bmi"], bins=20)
plt.title("BMI")
plt.show()

# %% [markdown]
# Q5

# %%
sns.countplot(x="sex", data=df)
plt.show()

# %%
sns.countplot(x="smoker", data=df)
plt.show()

# %%
sns.countplot(x="region", data=df)
plt.show()

# %% [markdown]
# Q6

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

# %% [markdown]
# Q7

# %%
X = df.drop("expenses", axis=1)
y = df["expenses"]

# %% [markdown]
# Q8

# %%
df[["sex","smoker"]].head()
# Out:
#       sex smoker
# 0  female    yes
# 1    male     no
# 2    male     no
# 3    male     no
# 4    male     no

# %%
X = pd.get_dummies(X, drop_first=True)

# %%
X.head()
# Out:
#    age   bmi  children  sex_male  smoker_yes  region_northwest  \
# 0   19  27.9         0     False        True             False
# 1   18  33.8         1      True       False             False
# 2   28  33.0         3      True       False             False
# 3   33  22.7         0      True       False              True
# 4   32  28.9         0      True       False              True
#
#    region_southeast  region_southwest
# 0             False              True
# 1              True             False
# 2              True             False
# 3             False             False
# 4             False             False

# %% [markdown]
# Q9

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
pd.DataFrame(X_scaled, columns=X.columns).head()
# Out:
#         age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 0 -1.440418 -0.453484 -0.909234 -1.009771    1.969660         -0.565546
# 1 -1.511647  0.513986 -0.079442  0.990324   -0.507702         -0.565546
# 2 -0.799350  0.382803  1.580143  0.990324   -0.507702         -0.565546
# 3 -0.443201 -1.306169 -0.909234  0.990324   -0.507702          1.768203
# 4 -0.514431 -0.289506 -0.909234  0.990324   -0.507702          1.768203
#
#    region_southeast  region_southwest
# 0         -0.611638          1.764609
# 1          1.634955         -0.566698
# 2          1.634955         -0.566698
# 3         -0.611638         -0.566698
# 4         -0.611638         -0.566698

# %% [markdown]
# Q10

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

df = pd.read_csv("insurance.csv")

df = df.drop_duplicates()

plt.hist(df["expenses"])
plt.show()

sns.countplot(x="smoker", data=df)
plt.show()

sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.show()

X = df.drop("expenses", axis=1)
y = df["expenses"]

X = pd.get_dummies(X, drop_first=True)

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

pd.DataFrame(X_scaled, columns=X.columns).head()
# Out:
#         age       bmi  children  sex_male  smoker_yes  region_northwest  \
# 0 -1.440418 -0.453484 -0.909234 -1.009771    1.969660         -0.565546
# 1 -1.511647  0.513986 -0.079442  0.990324   -0.507702         -0.565546
# 2 -0.799350  0.382803  1.580143  0.990324   -0.507702         -0.565546
# 3 -0.443201 -1.306169 -0.909234  0.990324   -0.507702          1.768203
# 4 -0.514431 -0.289506 -0.909234  0.990324   -0.507702          1.768203
#
#    region_southeast  region_southwest
# 0         -0.611638          1.764609
# 1          1.634955         -0.566698
# 2          1.634955         -0.566698
# 3         -0.611638         -0.566698
# 4         -0.611638         -0.566698
